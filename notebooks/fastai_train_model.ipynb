# %% [markdown]
# # Import the packages

# %%
import os

from fastai.vision.all import *
from fastai.vision import *

import pandas as pd

# %% [markdown]
# # Convert the dataset into Imagenet style

# %%
DATASET_PATH = '/media/ryan/New Volume/datasets/kagglecatsanddogs_5340/PetImages'
DATASET_PATH_Train = '/media/ryan/New Volume/datasets/kagglecatsanddogs_5340/PetImages/Train'
DATASET_PATH_Val = '/media/ryan/New Volume/datasets/kagglecatsanddogs_5340/PetImages/Val'
DATASET_PATH_Test = '/media/ryan/New Volume/datasets/kagglecatsanddogs_5340/PetImages/Test'

# %%
class_names = []
for folder_name in os.listdir(DATASET_PATH_Train):
    if not folder_name.endswith('.csv'):
        class_names.append(folder_name)

# %%
class_names
# Out:
# ['Cat', 'Dog']

# %%
image_paths_train = []
labels_train = []

for i in range(len(class_names)):
    class_name = class_names[i]
    image_names = os.listdir(f'{DATASET_PATH_Train}/{class_name}')
    for image_name in image_names:
        image_path = f'{DATASET_PATH}/{class_name}/{image_name}'
        image_paths_train.append(image_path)
        labels_train.append(i)

# %%
df_train = pd.DataFrame(
    {
        'name': image_paths_train,
        'label': labels_train
    }
)

# %%
df_train.head()
# Out:
#                                                                             name  \
# 0     /media/ryan/New Volume/datasets/kagglecatsanddogs_5340/PetImages/Cat/0.jpg
# 1     /media/ryan/New Volume/datasets/kagglecatsanddogs_5340/PetImages/Cat/1.jpg
# 2    /media/ryan/New Volume/datasets/kagglecatsanddogs_5340/PetImages/Cat/10.jpg
# 3   /media/ryan/New Volume/datasets/kagglecatsanddogs_5340/PetImages/Cat/100.jpg
# 4  /media/ryan/New Volume/datasets/kagglecatsanddogs_5340/PetImages/Cat/1000.jpg
#
#    label
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
df_train.tail()
# Out:
#                                                                                 name  \
# 21985  /media/ryan/New Volume/datasets/kagglecatsanddogs_5340/PetImages/Dog/9995.jpg
# 21986  /media/ryan/New Volume/datasets/kagglecatsanddogs_5340/PetImages/Dog/9996.jpg
# 21987  /media/ryan/New Volume/datasets/kagglecatsanddogs_5340/PetImages/Dog/9997.jpg
# 21988  /media/ryan/New Volume/datasets/kagglecatsanddogs_5340/PetImages/Dog/9998.jpg
# 21989  /media/ryan/New Volume/datasets/kagglecatsanddogs_5340/PetImages/Dog/9999.jpg
#
#        label
# 21985      1
# 21986      1
# 21987      1
# 21988      1
# 21989      1

# %%
df_train.to_csv(
    path_or_buf=f'{DATASET_PATH_Train}/labels.csv',
    index=False
)

# %%
image_paths_val = []
labels_val = []

for i in range(len(class_names)):
    class_name = class_names[i]
    image_names = os.listdir(f'{DATASET_PATH_Val}/{class_name}')
    for image_name in image_names:
        image_path = f'{DATASET_PATH}/{class_name}/{image_name}'
        image_paths_val.append(image_path)
        labels_val.append(i)


df_val = pd.DataFrame(
    {
        'name': image_paths_val,
        'label': labels_val
    }
)

df_val.to_csv(
    path_or_buf=f'{DATASET_PATH_Val}/labels.csv',
    index=False
)

# %%
image_paths_test = []
labels_test = []

for i in range(len(class_names)):
    class_name = class_names[i]
    image_names = os.listdir(f'{DATASET_PATH_Test}/{class_name}')
    for image_name in image_names:
        image_path = f'{DATASET_PATH}/{class_name}/{image_name}'
        image_paths_test.append(image_path)
        labels_test.append(i)


df_val = pd.DataFrame(
    {
        'name': image_paths_test,
        'label': labels_test
    }
)

df_val.to_csv(
    path_or_buf=f'{DATASET_PATH_Test}/labels.csv',
    index=False
)

# %% [markdown]
# # Load the data

# %%
dls = ImageDataLoaders.from_folder(
    path=DATASET_PATH,
    train = 'Train',
    valid = 'Val',
    test = 'Test',
    item_tfms=Resize(224),
    bs=16,
    batch_tfms=[Normalize.from_stats(*imagenet_stats), RandTransform()],
    device = 'cuda'
)

# %%
dls.show_batch()

# %% [markdown]
# # Create a model

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
model = vision_learner(
    dls=dls,
    arch=models.resnet50,
    metrics=[accuracy, error_rate]
)
model.to('cuda') 
print(next(model.model.parameters()).device)
# Out:
# cuda:0

# %%
model.fine_tune(
    epochs=1
)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.140416</td>
#       <td>0.044891</td>
#       <td>0.986987</td>
#       <td>0.013013</td>
#       <td>01:15</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.054297</td>
#       <td>0.025508</td>
#       <td>0.992492</td>
#       <td>0.007508</td>
#       <td>01:44</td>
#     </tr>
#   </tbody>
# </table>

# %%
model.show_results()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp = Interpretation.from_learner(model)
interp.plot_top_losses(k=12)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='125' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/125 00:00&lt;?]
#     </div>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %% [markdown]
# # Save the model

# %%
model.export(f'{DATASET_PATH}/catdog_classifier_1.pkl')

# %% [markdown]
# # Load the model

# %%
new_model = load_learner(f'{DATASET_PATH}/catdog_classifier_1.pkl')

# %% [markdown]
# # Predict from the loaded model

# %%
test_results = learn.validate(dl=dls.test)
print("Test set results:")
print(f" - Loss: {test_results[0]}")
print(f" - Accuracy: {test_results[1]}")
